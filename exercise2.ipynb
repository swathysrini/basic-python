# %%
import numpy as n
import pandas as p
import matplotlib.pyplot as plt
import seaborn as s

# %%
data = p.read_csv('C:/Users/CUIC/Downloads/AI_ML/Certificate_Programme_in_AI_ML_B2-master/11.2 Chennai Institute of Technology_202114-11-19.csv')

# %%
data
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 0            ASHOK KUMAR K     100          0     31                       9
# 1                  Chandru       0         20      0                       0
# 2        Ganesh Ramkumar R      -1         55     24                       6
# 3          Bodipudi Harini      -1          0     35                      -1
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# ...

# %%
e = data[data['CodeKata Score']>15000]
e
# Out:
#             Name  python  python_en  mysql  computational_thinking  \
# 0  ASHOK KUMAR K     100          0     31                       9
#
#    Previous Geekions  CodeKata Score                              Department  \
# 0              19400           19400  Electronics and Electrical Engineering
#
#        Mobile                             Email  Rising
# 0  6382040562  ashokkumark.citeee2017@gmail.com       0

# %%
e.to_csv('expectations.csv')

# %%
f = data[data['CodeKata Score'].between(10000,15000)]
f
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
#
#    Previous Geekions  CodeKata Score  \
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
#
#                                   Department      Mobile  \
# 1           Computer Science and Engineering  8667881378
# 2           Computer Science and Engineering  9003671061
# 3  Electronics and Communication Engineering  8374994636
#
#                            Email  Rising
# 1  chandrus.citcse2017@gmail.com     340
# 2    science.ganesh007@gmail.com    2000
# 3   harinib.citece2017@gmail.com       0

# %%
f.to_csv('Reached_expectations.csv')
f

# %%
g = data[data['CodeKata Score'].between(7000,10000)]
g
# Out:
#                       Name  python  python_en  mysql  computational_thinking  \
# 4                VIINU V P      -1        100     24                      -1
# 5               Poojitha Y       0         78     35                       0
# 6   Gowtham Chandrasekaran      -1          0      0                       3
# 7                Gowtham R      -1         60      4                       6
# 8                 shifak N      58          0      0                       0
# 9                  Balaji       -1        100     20                       0
# 10                Rushitha      -1         15     62                       9
# 11    Balaraman Muthupandi      -1          9      0                       0
# 12                JPradhap     100          0      0                       0
# 13           SRIRAMKUMAR B      -1          0      0                       0
# 14               Praneetha      -1         23    100                      -1
# ...

# %%
data[(data['CodeKata Score']<10000) & (data['CodeKata Score']>15000)]
# Out:
# Empty DataFrame
# Columns: [Name, python, python_en, mysql, computational_thinking, Previous Geekions, CodeKata Score, Department, Mobile, Email, Rising]
# Index: []

# %%
g.to_csv('Needs_expectations.csv')

# %%
data[data['CodeKata Score']<7000]
# Out:
#                  Name  python  python_en  mysql  computational_thinking  \
# 18     Narasimhan Y L      -1         -1      0                       0
# 19       Leelakrishna      -1          6      4                       0
# 20     PremsagarReddy      -1         20      0                       0
# 21          pradeeban      16         20     24                       0
# 22        santhoshini      -1         43      0                       0
# 23         MUKESH S M      -1         46      0                       0
# 24      P.GOVARDHANAN      -1         40      0                      -1
# 25       SHAIK DANISH      -1         43      0                       0
# 26          sridhar.s      -1         52      0                       0
# 27  Vimalesh Fernando      -1          0      0                       0
# 28      M.Karthikeyan      -1          0      4                       6
# 29          Abishak s      -1         55     35                       6
# ...

# %%
data[(data['Previous Geekions'].mean()) & (data['Previous Geekions'].mean())].mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-8078d970acf1> in <module>
# ----> 1 data[(data['Previous Geekions'].mean()) & (data['Previous Geekions'].mean())].mean()
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
data['CodeKata Score'].mean()
# Out:
# 6801.428571428572

# %%
data['Name'].count()
# Out:
# 35

# %%
data['Rising'].value_counts()
# Out:
# 0       14
# 2000     2
# 1760     1
# 770      1
# 1340     1
# 3140     1
# 1990     1
# 840      1
# 340      1
# 30       1
# 380      1
# 1360     1
# 1540     1
# 1830     1
# 1000     1
# 320      1
# 620      1
# 580      1
# 560      1
# 690      1
# 1700     1
# Name: Rising, dtype: int64
